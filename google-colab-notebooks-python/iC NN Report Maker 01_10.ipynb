# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import json
import matplotlib.pyplot as plt

# %%
accuracies = []
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-01-10 With 2 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-01-10 With 3 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-01-10 With 4 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-01-10 With 5 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-01-10 With 6 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-01-10 With 7 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-01-10 With 8 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-01-10 With 9 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-01-10 With 10 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-01-10 With 11 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-01-10 With 12 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-01-10 With 13 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-01-10 With 14 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-01-10 With 15 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-01-10 With 16 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-01-10 With 17 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-01-10 With 18 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-01-11 With 19 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-01-12 With 20 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
# with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-01-12 With 21 Attributes.json", "r") as f:
#   rep = json.load(f)
# accuracies.append(rep["accuracy_test"])

print(accuracies)

max_acc = max(accuracies)
min_acc = min(accuracies)
len_acc = len(accuracies)

xc = range(2,len_acc+2)
plt.figure()
plt.plot(xc, accuracies)
plt.ylabel('Test Accuracy')
plt.xlabel('Number of Attributes')
plt.title('Test Accuracy by Number of Attributes using attributes connection weights')

y=np.arange(0.8,0.99,0.005)
z=np.arange(min_acc,max_acc,0.005)

plt.xticks(range(len(accuracies)+2))
plt.yticks(y)
plt.ylim(min_acc-0.0025, max_acc+0.0025)
for i in y:
  plt.axhline(i, color="black", linestyle=":")
for i in range(0,len_acc+2,2):
  plt.axvline(i, color="black", linestyle=":")

plt.savefig('/content/drive/MyDrive/IC-Skynet/NNreports/IC NN attributes weights0110')

print()
# Out:
# [0.8833662271499634, 0.9176505208015442, 0.9171463251113892, 0.9176925420761108, 0.9162220358848572, 0.9179025888442993, 0.9079450368881226, 0.9488256573677063, 0.9524389505386353, 0.9531532526016235, 0.9490357637405396, 0.9505482912063599, 0.959539532661438, 0.9573127031326294, 0.9560102224349976, 0.957354724407196, 0.9567665457725525, 0.9572706818580627, 0.9590773582458496]
