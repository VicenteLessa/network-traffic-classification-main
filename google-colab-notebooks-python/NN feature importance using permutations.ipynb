# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import datetime
import json
import numpy as np
import os
import pandas as pd
import sys 
import tensorflow as tf
import time
import matplotlib.pyplot as plt

from keras.callbacks import History 
history = History()

BATCH_SIZE = 10
number_of_attributes = 35

number_of_permutations = 33 # for each attribute

print(tf.__version__)
# Out:
# 2.8.0

# %%
path_training ="/content/drive/MyDrive/network-traffic-classification-main/csv-files/01_Atributos_Weve.csv"
path_test ="/content/drive/MyDrive/network-traffic-classification-main/csv-files/02_Atributos_Weve.csv"
df_raw = pd.read_csv(path_training)
df_test_raw = pd.read_csv(path_test)
df_raw
target = df_raw.pop('target')
server_port = df_raw.pop('ServerPort')
client_port = df_raw.pop('ClientPort')

target_test = df_test_raw.pop('target')
server_port_test = df_test_raw.pop('ServerPort')
client_port = df_test_raw.pop('ClientPort')

attributes_array = ['10','15','17','22','24','29','31','32','33','34','36','37','38','45','46','47','48','59','60','61','62','63','64','79','80','81','82','83','84','87','88','89','90','91','92','75','76','77','78']

# %%
classes = ['WWW','MAIL','FTP-CONTROL','FTP-PASV','ATTACK','P2P','DATABASE','FTP-DATA','MULTIMEDIA','SERVICES','INTERACTIVE','GAMES']
#classes = list(target.unique())
#classes
#Converts the above list of classes to an array of index
target = target.apply(lambda x: classes.index(x))
target.unique()
target_test = target_test.apply(lambda x: classes.index(x))

# %%
def get_basic_model():
  model = tf.keras.Sequential([
    normalizer,
    tf.keras.layers.Dense(10, activation='relu'), 
    tf.keras.layers.Dense(12)
  ])

  model.compile(optimizer='adam',
                loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                metrics=['accuracy'])
  return model

# %%
# Select a sub-dataframe from the main dataframe with a lower number of attributes
df = df_raw[attributes_array[0:number_of_attributes]]
df_test = df_test_raw[attributes_array[0:number_of_attributes]]

print(df_test)

# Combine the data with possible classes
numeric_feature_names = attributes_array[0:number_of_attributes]
numeric_features = df[numeric_feature_names] # Data for training
numeric_features_test = df_test[numeric_feature_names] # Data for testing

# Converts pandas dataframe to tensorflow object
numeric_features = tf.convert_to_tensor(numeric_features)
#numeric_features_test = tf.convert_to_tensor(numeric_features_test) botei na célula abaixo

# Normalize the data
normalizer = tf.keras.layers.Normalization(axis=-1)
normalizer.adapt(numeric_features)
#normalizer.adapt(numeric_features_test)

# Execute Trainning and Testing
model = get_basic_model()
print('Starting training for',number_of_attributes,'attributes')
history = model.fit(numeric_features, target, epochs=10, verbose=0, batch_size=BATCH_SIZE, callbacks=[history])
train_accuracy = history.history['accuracy']
print('train_accuracy:', train_accuracy)
# Out:
#        10    15  17    22  24  29  31  ...   84     87     88     89     90  91  92
# 0      66   503  52   489  14  14   7  ...  398   6432  24616   5840  24334   0   0
# 1      66   465  52   451  14  14   6  ...  399   6432  24616   5840  24616   0   0
# 2      66   464  52   450  14  14   6  ...  398   6432  24616   5840  24616   0   0
# 3      66   465  52   451  14  14   6  ...  399   6432  24616   5840  24616   0   0
# 4      66   682  52   668  14  14   6  ...  399   6432  24616   5840  24334   0   0
# ...    ..   ...  ..   ...  ..  ..  ..  ...  ...    ...    ...    ...    ...  ..  ..
# 23796  60  1514  40  1500  14  20  14  ...   21  17520  58400  16384  56940   0   0
# 23797  60  1414  40  1400  14  20  16  ...   21  17680  58480  16384  57120   0   0
# 23798  60  1514  40  1500  14  20  14  ...  759  33580  61440  32821  61440   0   0
# 23799  60   989  40   975  14  20   7  ...  449  33580  61440  33580  61440   0   0
# 23800  60  1514  40  1500  14  20  24  ...    2  33580  61440  31845  61440   0   0
#
# [23801 rows x 35 columns]
# Starting training for 35 attributes
# train_accuracy: [0.8973172903060913, 0.9534247517585754, 0.9652897715568542, 0.9726501107215881, 0.9763101935386658, 0.977436363697052, 0.9784016609191895, 0.9790451526641846, 0.9800909161567688, 0.9801713228225708]

# %%
test_loss, test_acc =  model.evaluate(numeric_features_test, target_test, verbose=0, batch_size=BATCH_SIZE)

permutated_accuracy_means_array = []

#for every attribute
for attr_i, attr in enumerate(numeric_features_test.columns):
  print(f"Running attr: {attr}")  
  
  permutated_accuracy_array = []  
  # run n times for each attribute
  for n in range(number_of_permutations):  
    df_permutated = numeric_features_test.copy()
    df_permutated[attr] = np.random.permutation(df_permutated[attr].values)
    #display('original:',numeric_features_test[attr])
    #display('permutaded',df_permutated[attr])

    df_permutated = tf.convert_to_tensor(df_permutated)      
    permutated_loss, permutated_acc = model.evaluate(df_permutated,  target_test, verbose=0, batch_size=BATCH_SIZE)  
    permutated_accuracy_array.append(permutated_acc)

  print('permutated_accuracy_array:',permutated_accuracy_array)
  permutated_accuracy_mean = sum(permutated_accuracy_array) / len(permutated_accuracy_array)  
  print('permutated_accuracy_mean',permutated_accuracy_mean)
  ratio = permutated_accuracy_mean / test_acc
  print(f"Original Accuracy: {test_acc:.3f} Permutated Accuracy: {permutated_accuracy_mean:.3f} Ratio: {ratio:.3f}\n")

  permutated_accuracy_means_array.append((permutated_accuracy_mean, numeric_feature_names[attr_i])) 
  #print('permutated_accuracy_means_array',permutated_accuracy_means_array,'\n')
  #if attr_i > 3: break

permutated_accuracy_means_array = sorted(permutated_accuracy_means_array)
print('permutated_accuracy_means_array SORTED',permutated_accuracy_means_array)
attributes = [x for _, x in permutated_accuracy_means_array]
print('sorted attributes', attributes)

# Date for report file
current_date_and_time = datetime.date.today()
current_date_and_time_string = str(current_date_and_time)
# Report file content
attr_report = {
    "datetime": current_date_and_time_string,
    "sorted_attributes_by_weights": attributes
}
# Writes into the file
attr_title = "/content/drive/MyDrive/network-traffic-classification-main/nn-attribute-arrays/%s"%current_date_and_time_string
with open(attr_title, "w") as f:
  json.dump(attr_report , f)
with open("/content/drive/MyDrive/network-traffic-classification-main/nn-attribute-arrays/last-run", "w") as f:
  json.dump(attr_report , f)
with open(attr_title, "r") as f:
  rep = json.load(f)
  display(rep)
# Out:
# Running attr: 10
# permutated_accuracy_array: [0.9294567704200745]
# permutated_accuracy_mean 0.9294567704200745
# Original Accuracy: 0.947 Permutated Accuracy: 0.929 Ratio: 0.982
#
# Running attr: 15
# permutated_accuracy_array: [0.943825900554657]
# permutated_accuracy_mean 0.943825900554657
# Original Accuracy: 0.947 Permutated Accuracy: 0.944 Ratio: 0.997
#
# Running attr: 17
# permutated_accuracy_array: [0.9329019784927368]
# permutated_accuracy_mean 0.9329019784927368
# Original Accuracy: 0.947 Permutated Accuracy: 0.933 Ratio: 0.986
#
# Running attr: 22
# permutated_accuracy_array: [0.9497079849243164]
# permutated_accuracy_mean 0.9497079849243164
# Original Accuracy: 0.947 Permutated Accuracy: 0.950 Ratio: 1.003
#
# Running attr: 24
# permutated_accuracy_array: [0.9463468194007874]
# permutated_accuracy_mean 0.9463468194007874
# Original Accuracy: 0.947 Permutated Accuracy: 0.946 Ratio: 1.000
#
# Running attr: 29
# permutated_accuracy_array: [0.9350027441978455]
# permutated_accuracy_mean 0.9350027441978455
# Original Accuracy: 0.947 Permutated Accuracy: 0.935 Ratio: 0.988
#
# Running attr: 31
# permutated_accuracy_array: [0.9465568661689758]
# permutated_accuracy_mean 0.9465568661689758
# Original Accuracy: 0.947 Permutated Accuracy: 0.947 Ratio: 1.000
#
# Running attr: 32
# permutated_accuracy_array: [0.9458006024360657]
# permutated_accuracy_mean 0.9458006024360657
# Original Accuracy: 0.947 Permutated Accuracy: 0.946 Ratio: 0.999
#
# Running attr: 33
# permutated_accuracy_array: [0.9464308023452759]
# permutated_accuracy_mean 0.9464308023452759
# Original Accuracy: 0.947 Permutated Accuracy: 0.946 Ratio: 1.000
#
# Running attr: 34
# permutated_accuracy_array: [0.9464308023452759]
# permutated_accuracy_mean 0.9464308023452759
# Original Accuracy: 0.947 Permutated Accuracy: 0.946 Ratio: 1.000
#
# Running attr: 36
# permutated_accuracy_array: [0.9460526704788208]
# permutated_accuracy_mean 0.9460526704788208
# Original Accuracy: 0.947 Permutated Accuracy: 0.946 Ratio: 0.999
#
# Running attr: 37
# permutated_accuracy_array: [0.9461367130279541]
# permutated_accuracy_mean 0.9461367130279541
# Original Accuracy: 0.947 Permutated Accuracy: 0.946 Ratio: 1.000
#
# Running attr: 38
# permutated_accuracy_array: [0.9464308023452759]
# permutated_accuracy_mean 0.9464308023452759
# Original Accuracy: 0.947 Permutated Accuracy: 0.946 Ratio: 1.000
#
# Running attr: 45
# permutated_accuracy_array: [0.9451703429222107]
# permutated_accuracy_mean 0.9451703429222107
# Original Accuracy: 0.947 Permutated Accuracy: 0.945 Ratio: 0.998
#
# Running attr: 46
# permutated_accuracy_array: [0.9463887810707092]
# permutated_accuracy_mean 0.9463887810707092
# Original Accuracy: 0.947 Permutated Accuracy: 0.946 Ratio: 1.000
#
# Running attr: 47
# permutated_accuracy_array: [0.9454644918441772]
# permutated_accuracy_mean 0.9454644918441772
# Original Accuracy: 0.947 Permutated Accuracy: 0.945 Ratio: 0.999
#
# Running attr: 48
# permutated_accuracy_array: [0.9459686279296875]
# permutated_accuracy_mean 0.9459686279296875
# Original Accuracy: 0.947 Permutated Accuracy: 0.946 Ratio: 0.999
#
# Running attr: 59
# permutated_accuracy_array: [0.9401285648345947]
# permutated_accuracy_mean 0.9401285648345947
# Original Accuracy: 0.947 Permutated Accuracy: 0.940 Ratio: 0.993
#
# Running attr: 60
# permutated_accuracy_array: [0.9434057474136353]
# permutated_accuracy_mean 0.9434057474136353
# Original Accuracy: 0.947 Permutated Accuracy: 0.943 Ratio: 0.997
#
# Running attr: 61
# permutated_accuracy_array: [0.9468929767608643]
# permutated_accuracy_mean 0.9468929767608643
# Original Accuracy: 0.947 Permutated Accuracy: 0.947 Ratio: 1.000
#
# Running attr: 62
# permutated_accuracy_array: [0.9454224705696106]
# permutated_accuracy_mean 0.9454224705696106
# Original Accuracy: 0.947 Permutated Accuracy: 0.945 Ratio: 0.999
#
# Running attr: 63
# permutated_accuracy_array: [0.9466829299926758]
# permutated_accuracy_mean 0.9466829299926758
# Original Accuracy: 0.947 Permutated Accuracy: 0.947 Ratio: 1.000
#
# Running attr: 64
# permutated_accuracy_array: [0.9455904960632324]
# permutated_accuracy_mean 0.9455904960632324
# Original Accuracy: 0.947 Permutated Accuracy: 0.946 Ratio: 0.999
#
# Running attr: 79
# permutated_accuracy_array: [0.919877290725708]
# permutated_accuracy_mean 0.919877290725708
# Original Accuracy: 0.947 Permutated Accuracy: 0.920 Ratio: 0.972
#
# Running attr: 80
# permutated_accuracy_array: [0.9516406655311584]
# permutated_accuracy_mean 0.9516406655311584
# Original Accuracy: 0.947 Permutated Accuracy: 0.952 Ratio: 1.005
#
# Running attr: 81
# permutated_accuracy_array: [0.943321704864502]
# permutated_accuracy_mean 0.943321704864502
# Original Accuracy: 0.947 Permutated Accuracy: 0.943 Ratio: 0.997
#
# Running attr: 82
# permutated_accuracy_array: [0.9091214537620544]
# permutated_accuracy_mean 0.9091214537620544
# Original Accuracy: 0.947 Permutated Accuracy: 0.909 Ratio: 0.960
#
# Running attr: 83
# permutated_accuracy_array: [0.8377799391746521]
# permutated_accuracy_mean 0.8377799391746521
# Original Accuracy: 0.947 Permutated Accuracy: 0.838 Ratio: 0.885
#
# Running attr: 84
# permutated_accuracy_array: [0.927608072757721]
# permutated_accuracy_mean 0.927608072757721
# Original Accuracy: 0.947 Permutated Accuracy: 0.928 Ratio: 0.980
#
# Running attr: 87
# permutated_accuracy_array: [0.9408848285675049]
# permutated_accuracy_mean 0.9408848285675049
# Original Accuracy: 0.947 Permutated Accuracy: 0.941 Ratio: 0.994
#
# Running attr: 88
# permutated_accuracy_array: [0.9387840628623962]
# permutated_accuracy_mean 0.9387840628623962
# Original Accuracy: 0.947 Permutated Accuracy: 0.939 Ratio: 0.992
#
# Running attr: 89
# permutated_accuracy_array: [0.94227135181427]
# permutated_accuracy_mean 0.94227135181427
# Original Accuracy: 0.947 Permutated Accuracy: 0.942 Ratio: 0.995
#
# Running attr: 90
# permutated_accuracy_array: [0.9214318990707397]
# permutated_accuracy_mean 0.9214318990707397
# Original Accuracy: 0.947 Permutated Accuracy: 0.921 Ratio: 0.973
#
# Running attr: 91
# permutated_accuracy_array: [0.946262776851654]
# permutated_accuracy_mean 0.946262776851654
# Original Accuracy: 0.947 Permutated Accuracy: 0.946 Ratio: 1.000
#
# Running attr: 92
# permutated_accuracy_array: [0.9473971724510193]
# permutated_accuracy_mean 0.9473971724510193
# Original Accuracy: 0.947 Permutated Accuracy: 0.947 Ratio: 1.001
#
# permutated_accuracy_means_array SORTED [(0.8377799391746521, '83'), (0.9091214537620544, '82'), (0.919877290725708, '79'), (0.9214318990707397, '90'), (0.927608072757721, '84'), (0.9294567704200745, '10'), (0.9329019784927368, '17'), (0.9350027441978455, '29'), (0.9387840628623962, '88'), (0.9401285648345947, '59'), (0.9408848285675049, '87'), (0.94227135181427, '89'), (0.943321704864502, '81'), (0.9434057474136353, '60'), (0.943825900554657, '15'), (0.9451703429222107, '45'), (0.9454224705696106, '62'), (0.9454644918441772, '47'), (0.9455904960632324, '64'), (0.9458006024360657, '32'), (0.9459686279296875, '48'), (0.9460526704788208, '36'), (0.9461367130279541, '37'), (0.946262776851654, '91'), (0.9463468194007874, '24'), (0.9463887810707092, '46'), (0.9464308023452759, '33'), (0.9464308023452759, '34'), (0.9464308023452759, '38'), (0.9465568661689758, '31'), (0.9466829299926758, '63'), (0.9468929767608643, '61'), (0.9473971724510193, '92'), (0.9497079849243164, '22'), (0.9516406655311584, '80')]
# sorted attributes ['83', '82', '79', '90', '84', '10', '17', '29', '88', '59', '87', '89', '81', '60', '15', '45', '62', '47', '64', '32', '48', '36', '37', '91', '24', '46', '33', '34', '38', '31', '63', '61', '92', '22', '80']
# {'datetime': '2022-03-02',
#  'sorted_attributes_by_weights': ['83',
#   '82',
#   '79',
#   '90',
#   '84',
#   '10',
#   '17',
#   '29',
#   '88',
#   '59',
#   '87',
#   '89',
#   '81',
#   '60',
#   '15',
#   '45',
#   '62',
#   '47',
#   '64',
#   '32',
#   '48',
#   '36',
#   '37',
#   '91',
#   '24',
#   '46',
#   '33',
#   '34',
#   '38',
#   '31',
#   '63',
#   '61',
#   '92',
#   '22',
#   '80']}
