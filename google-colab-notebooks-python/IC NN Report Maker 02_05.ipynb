# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json
import matplotlib.pyplot as plt
import numpy as np

# %%
accuracies = []
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-05 With 2 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-05 With 3 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-05 With 4 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-05 With 5 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-05 With 6 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-05 With 7 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-05 With 8 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-05 With 9 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-05 With 10 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-05 With 11 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-05 With 12 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-05 With 13 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-05 With 14 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-05 With 15 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-05 With 16 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-05 With 17 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-05 With 18 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-05 With 19 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-05 With 20 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])


print(accuracies)

max_acc = max(accuracies)
min_acc = min(accuracies)
len_acc = len(accuracies)

xc = range(2,len_acc+2)
plt.figure()
plt.plot(xc, accuracies)
plt.ylabel('Test Accuracy')
plt.xlabel('Number of Attributes')
plt.title('Test Accuracy by Number of Attributes using Permutation Shuffing')

y=np.arange(0.9,0.99,0.005)
z=np.arange(min_acc,max_acc,0.005)

plt.xticks(range(len(accuracies)+2))
plt.yticks(y)
plt.ylim(min_acc-0.0025, max_acc+0.0025)
for i in y:
  plt.axhline(i, color="black", linestyle=":")
for i in range(0,len_acc+2,2):
  plt.axvline(i, color="black", linestyle=":")

plt.savefig('/content/drive/MyDrive/IC-Skynet/NNreports/IC NN Permutations0205')



print()
# Out:
# [0.9232343196868896, 0.9285870373249054, 0.9299105107784271, 0.9467564404010773, 0.9460148721933365, 0.9479244530200959, 0.9463173776865006, 0.951651194691658, 0.9489454180002213, 0.9526091337203979, 0.95281081199646, 0.9527414858341217, 0.9530208855867386, 0.9546258538961411, 0.955573296546936, 0.9560375601053238, 0.9587055206298828, 0.9566698879003525, 0.9589912176132203]

# %%
# a = ['83', '82', '79', '22', '90', '84', '88', '15', '60', '17', '29', '80', '89', '87', '81', '59', '45', '47', '10', '31', '37', '33', '36', '64', '62', '38', '32', '24', '34', '91', '63', '92', '61', '48', '46']
# b = ['83', '82', '79', '90', '10', '88', '29', '22', '84', '17', '59', '89', '81', '80', '87', '60', '64', '47', '33', '31', '62', '45', '36', '34', '63', '37', '38', '91', '32', '24', '46', '48', '61', '15', '92']
# c = ['60', '59', '82', '46', '17', '84', '79', '10', '90', '15', '24', '92', '91', '83', '48', '37', '22', '88', '47', '45', '34', '32', '36', '38', '33', '31', '80', '61', '62', '64', '89', '63', '29', '87', '81', '75','76','77','78']

# for ix, attr in a,b,c:
